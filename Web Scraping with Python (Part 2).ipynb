# %% [markdown]
# ## Web Scraping with Python (Part 2)

# %% [markdown]
# ### Summary
# In this notebook, we will explore and collect data from the Oceano de Rent website using the Beautiful Soup library. Next, we will analyze all the information collected.
#
# ### To know more:
# * Samsung Ocean lectures and courses.
# * Ryan Mitchell. Web Scraping with Python: Collecting More Data from the Modern Web. Novatec Editora, 2019.
#
# ### 1) Creating the Beautiful Soup objects

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url_sobre = 'https://ocean-web-scraping.herokuapp.com/sobre.html'
url_busca = 'https://ocean-web-scraping.herokuapp.com/'
url_corretoras = 'https://ocean-web-scraping.herokuapp.com/corretoras.html'

# %% [markdown]
# #### 1.1) 'About' Page

# %%
response_sobre = urlopen(url_sobre)
html_sobre = response_sobre.read()
html_sobre
# Out:
# b'<!DOCTYPE html>\n<html lang="pt-br">\n\t<head>\n\t\t<meta charset="UTF-8">\n\t\t<meta name="viewport" content="width=device-width">\n\n\t\t<title>Oceano de Alugu\xc3\xa9is</title>\n\t\t\n\t\t<link rel="stylesheet" href="reset.css">\n\t\t<link rel="stylesheet" href="style.css">\n\t\t<link href="https://fonts.googleapis.com/css?family=Montserrat&display=swap" rel="stylesheet">\n\t</head>\n\n\t<body>\n\t\t<header>\n\t\t\t<div>\n\t\t\t\t<img src="imagens/oceano-logo.png">\n\t\t\t\t<h1>Oceano de Alugu\xc3\xa9is</h1>\n\t\t\t\t<nav>\n\t\t\t\t\t<ul>\n\t\t\t\t\t\t<li><a href="results&page=1.html">Resultados</a></li>\n\t\t\t\t\t\t<li><a href="corretoras.html">Corretoras</a></li>\n\t\t\t\t\t\t<li><a href="sobre.html">Sobre</a></li>\n\t\t\t\t\t</ul>\n\t\t\t\t</nav>\n\t\t\t</div>\n\t\t</header>\n\n\t\t<main>\n\t\t\t<div class="about">\n\t\t\t\t<h2>Sobre este site</h2>\n\n\t\t\t\t<p>Este site foi criado para treinamentos de Web Scraping do <a href="http://www.oceanbrasil.com/">Ocean</a>.</p>\n\n\t\t\t\t<p>Vamos para os primeiros desafios?</p>\n\n\t\t\t\t<ol>\n\t\t\t\t\t<li>Que tal coletar o texto <em>"Sobre este site"</em> para come\xc3\xa7ar?</li>\n\t\t\t\t\t<li>Agora extraia o link contido na palavra <em>"Ocean"</em>.</li>\n\t\t\t\t\t<li>Em seguida, colete todos os itens desta lista.</li>\n\t\t\t\t\t<li>Por fim, colete apenas este \xc3\xbaltimo item da lista.</li>\n\t\t\t\t</ol>\n\t\t\t</div>\n\t\t</main>\n\n\t\t<footer>\n\t\t\t<img src="imagens/oceano-logo-cinza.png">\n\t\t\t<p>Site criado com &#10084; para o curso de Web Scraping do Ocean.</p>\n\t\t</footer>\n\t</body>\n</html>'

# %%
soup_sobre = BeautifulSoup(html_sobre, 'html.parser')
soup_sobre
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>Oceano de Aluguéis</title>
# <link href="reset.css" rel="stylesheet"/>
# <link href="style.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" rel="stylesheet"/>
# </head>
# <body>
# <header>
# <div>
# <img src="imagens/oceano-logo.png"/>
# <h1>Oceano de Aluguéis</h1>
# <nav>
# <ul>
# <li><a href="results&amp;page=1.html">Resultados</a></li>
# <li><a href="corretoras.html">Corretoras</a></li>
# <li><a href="sobre.html">Sobre</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <main>
# <div class="about">
# <h2>Sobre este site</h2>
# <p>Este site foi criado para treinamentos de Web Scraping do <a href="http://www.oceanbrasil.com/">Ocean</a>.</p>
# <p>Vamos para os primeiros desafios?</p>
# <ol>
# <li>Que tal coletar o texto <em>"Sobre este site"</em> para começar?</li>
# <li>Agora extraia o link contido na palavra <em>"Ocean"</em>.</li>
# <li>Em seguida, colete todos os itens desta lista.</li>
# <li>Por fim, colete apenas este último item da lista.</li>
# </ol>
# </div>
# </main>
# <footer>
# <img src="imagens/oceano-logo-cinza.png"/>
# <p>Site criado com ❤ para o curso de Web Scraping do Ocean.</p>
# </footer>
# </body>
# </html>

# %% [markdown]
# #### 1.2) Real estate search results page

# %%
response_busca = urlopen(url_busca)
html_busca = response_busca.read()
html_busca
# Out:
# b'<!DOCTYPE html>\n<html lang="pt-br">\n\t<head>\n\t\t<meta charset="UTF-8">\n\t\t<meta name="viewport" content="width=device-width">\n\n\t\t<title>Oceano de Alugu\xc3\xa9is</title>\n\t\t\n\t\t<link rel="stylesheet" href="reset.css">\n\t\t<link rel="stylesheet" href="style.css">\n\t\t<link href="https://fonts.googleapis.com/css?family=Montserrat&display=swap" rel="stylesheet">\n\t</head>\n\n\t<body>\n\t\t<header>\n\t\t\t<div>\n\t\t\t\t<img src="imagens/oceano-logo.png">\n\t\t\t\t<h1>Oceano de Alugu\xc3\xa9is</h1>\n\t\t\t\t<nav>\n\t\t\t\t\t<ul>\n\t\t\t\t\t\t<li><a href="results&page=1.html">Resultados</a></li>\n\t\t\t\t\t\t<li><a href="corretoras.html">Corretoras</a></li>\n\t\t\t\t\t\t<li><a href="sobre.html">Sobre</a></li>\n\t\t\t\t\t</ul>\n\t\t\t\t</nav>\n\t\t\t</div>\n\t\t</header>\n\n\t\t<main>\n\t\t\t<div class="ad-card-list">\n\t\t\t\t<p>21 resultados obtidos - P\xc3\xa1gina 1</p>\n\n\t\t\t\t<div class="ad-card">\n\t\t\t\t\t<img src="imagens/apto-01.jpg" class="apto-img">\n\t\t\t\t\t\n\t\t\t\t\t<div class="ad-card-info">\n\t\t\t\t\t\t<h2>Lindo apartamento para alugar</h2>\n\n\t\t\t\t\t\t<ul class="features">\n\t\t\t\t\t\t\t<li><img src="imagens/area.png"> 100 m\xc2\xb2</li>\n\t\t\t\t\t\t\t<li><img src="imagens/bedrooms.png"> 3 quarto(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/toilet.png"> 2 banheiro(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/parking.png"> 2 vaga(s)</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<ul class="resources">\n\t\t\t\t\t\t\t<li>Mobiliado</li>\n\t\t\t\t\t\t\t<li>Portaria 24h</li>\n\t\t\t\t\t\t\t<li>Elevador</li>\n\t\t\t\t\t\t\t<li>Piscina</li>\n\t\t\t\t\t\t\t<li>Churrasqueira</li>\n\t\t\t\t\t\t\t<li>Sal\xc3\xa3o de Festas</li>\n\t\t\t\t\t\t\t<li>Academia</li>\n\t\t\t\t\t\t\t<li>Playground</li>\n\t\t\t\t\t\t\t<li>Quadra poliesportiva</li>\n\t\t\t\t\t\t\t<li>Sal\xc3\xa3o de jogos</li>\n\t\t\t\t\t\t\t<li>Aceita animais</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<p>Localiza\xc3\xa7\xc3\xa3o: Oceano Pac\xc3\xadfico</p>\n\t\t\t\t\t</div>\n\n\t\t\t\t\t<div class="ad-card-price">\n\t\t\t\t\t\t<p>Aluguel: R$ 4.000,00</p>\n\t\t\t\t\t\t<p>Condom\xc3\xadnio: 500,00</p>\n\t\t\t\t\t\t<p>IPTU: R$ 100,00</p>\n\t\t\t\t\t\t<p>Corretora: Tubar\xc3\xa3o</p>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\n\t\t\t\t<div class="ad-card">\n\t\t\t\t\t<img src="imagens/apto-02.jpg" class="apto-img">\n\t\t\t\t\t\n\t\t\t\t\t<div class="ad-card-info">\n\t\t\t\t\t\t<h2>\xc3\x93timo lugar para morar</h2>\n\n\t\t\t\t\t\t<ul class="features">\n\t\t\t\t\t\t\t<li><img src="imagens/area.png"> 60 m\xc2\xb2</li>\n\t\t\t\t\t\t\t<li><img src="imagens/bedrooms.png"> 2 quarto(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/toilet.png"> 2 banheiro(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/parking.png"> 1 vaga(s)</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<ul class="resources">\n\t\t\t\t\t\t\t<li>Mobiliado</li>\n\t\t\t\t\t\t\t<li>Portaria 24h</li>\n\t\t\t\t\t\t\t<li>Sal\xc3\xa3o de Festas</li>\n\t\t\t\t\t\t\t<li>Quadra poliesportiva</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<p>Localiza\xc3\xa7\xc3\xa3o: Oceano \xc3\x8dndico</p>\n\t\t\t\t\t</div>\n\n\t\t\t\t\t<div class="ad-card-price">\n\t\t\t\t\t\t<p>Aluguel: R$ 2.000,00</p>\n\t\t\t\t\t\t<p>Condom\xc3\xadnio: 200,00</p>\n\t\t\t\t\t\t<p>IPTU: R$ 50,00</p>\n\t\t\t\t\t\t<p>Corretora: Carangueijo</p>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\n\t\t\t\t<div class="ad-card">\n\t\t\t\t\t<img src="imagens/apto-03.jpg" class="apto-img">\n\t\t\t\t\t\n\t\t\t\t\t<div class="ad-card-info">\n\t\t\t\t\t\t<h2>Bel\xc3\xadssimo apartamento mobiliado</h2>\n\n\t\t\t\t\t\t<ul class="features">\n\t\t\t\t\t\t\t<li><img src="imagens/area.png"> 50 m\xc2\xb2</li>\n\t\t\t\t\t\t\t<li><img src="imagens/bedrooms.png"> 1 quarto(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/toilet.png"> 1 banheiro(s)</li>\n\t\t\t\t\t\t\t<li><img src="imagens/parking.png"> 1 vaga(s)</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<ul class="resources">\n\t\t\t\t\t\t\t<li>Mobiliado</li>\n\t\t\t\t\t\t</ul>\n\n\t\t\t\t\t\t<p>Localiza\xc3\xa7\xc3\xa3o: Mar de Java</p>\n\t\t\t\t\t</div>\ ...

# %%
soup_busca = BeautifulSoup(html_busca, 'html.parser')
soup_busca
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>Oceano de Aluguéis</title>
# <link href="reset.css" rel="stylesheet"/>
# <link href="style.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" rel="stylesheet"/>
# </head>
# <body>
# <header>
# <div>
# <img src="imagens/oceano-logo.png"/>
# <h1>Oceano de Aluguéis</h1>
# <nav>
# <ul>
# <li><a href="results&amp;page=1.html">Resultados</a></li>
# <li><a href="corretoras.html">Corretoras</a></li>
# <li><a href="sobre.html">Sobre</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <main>
# <div class="ad-card-list">
# <p>21 resultados obtidos - Página 1</p>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-02.jpg"/>
# <div class="ad-card-info">
# <h2>Ótimo lugar para morar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Salão de Festas</li>
# <li>Quadra poliesportiva</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 2.000,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Carangueijo</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-03.jpg"/>
# <div class="ad-card-info">
# <h2>Belíssimo apartamento mobiliado</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 50 m²</li>
# <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# </ul>
# <p>Localização: Mar de Java</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.300,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-04.jpg"/>
# <div class="ad-card-info">
# <h2>Um cantinho todo seu</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.800,00</p>
# <p>Condomínio: 100,00</p>
# <p>IPTU: R$ 20,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-05.jpg"/>
# <div class="ad-card-info">
# <h2>Alugue já! Ótima oportunidade</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 120 m²</li>
# <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 3.800,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 200,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# </div>
# <div class="pagination">
# <a class="inactive" href="#">«</a>
# <a class="active" href="#">1</a>
# <a href="results&amp;page=2.html">2</a>
# <a href="results&amp;page=3.html">3</a>
# <a href="results&amp;page=2.html">»</a>
# </div>
# </main>
# <footer>
# <img src="imagens/oceano-logo-cinza.png"/>
# <p>Site criado com ❤ para o curso de Web Scraping do Ocean.</p>
# </footer>
# </body>
# </html>

# %%
#soup_busca.prettify()

# %% [markdown]
# #### 1.3) Brokerage contact page

# %%
response_corretoras = urlopen(url_corretoras)
html_corretoras = response_corretoras.read()
html_corretoras
# Out:
# b'<!DOCTYPE html>\n<html lang="pt-br">\n\t<head>\n\t\t<meta charset="UTF-8">\n\t\t<meta name="viewport" content="width=device-width">\n\n\t\t<title>Oceano de Alugu\xc3\xa9is</title>\n\t\t\n\t\t<link rel="stylesheet" href="reset.css">\n\t\t<link rel="stylesheet" href="style.css">\n\t\t<link href="https://fonts.googleapis.com/css?family=Montserrat&display=swap" rel="stylesheet">\n\t</head>\n\n\t<body>\n\t\t<header>\n\t\t\t<div>\n\t\t\t\t<img src="imagens/oceano-logo.png">\n\t\t\t\t<h1>Oceano de Alugu\xc3\xa9is</h1>\n\t\t\t\t<nav>\n\t\t\t\t\t<ul>\n\t\t\t\t\t\t<li><a href="results&page=1.html">Resultados</a></li>\n\t\t\t\t\t\t<li><a href="corretoras.html">Corretoras</a></li>\n\t\t\t\t\t\t<li><a href="sobre.html">Sobre</a></li>\n\t\t\t\t\t</ul>\n\t\t\t\t</nav>\n\t\t\t</div>\n\t\t</header>\n\n\t\t<main>\n\t\t\t<div class="contacts">\n\t\t\t\t<table>\n\t\t\t\t\t<thead>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<th>Corretora</th>\n\t\t\t\t\t\t\t<th>Contatos</th>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t</thead>\n\n\t\t\t\t\t<tbody>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td>Tubar\xc3\xa3o</td>\n\t\t\t\t\t\t\t<td>Jo\xc3\xa3o Marinho - Fone:(XX)XXXX-XXXX</td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td>Carangueijo</td>\n\t\t\t\t\t\t\t<td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebasti\xc3\xa3o Costa - Fone:(XX)XXXX-XXXX</td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td>Baleia Azul</td>\n\t\t\t\t\t\t\t<td>\n\t\t\t\t\t\t\t\t<ul>\n\t\t\t\t\t\t\t\t\t<li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>\n\t\t\t\t\t\t\t\t\t<li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>\n\t\t\t\t\t\t\t\t</ul>\n\t\t\t\t\t\t\t</td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t\t<tr>\n\t\t\t\t\t\t\t<td>Enguia</td>\n\t\t\t\t\t\t\t<td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>\n\t\t\t\t\t\t</tr>\n\t\t\t\t\t</tbody>\n\t\t\t\t</table>\n\t\t\t</div>\n\t\t</main>\n\n\t\t<footer>\n\t\t\t<img src="imagens/oceano-logo-cinza.png">\n\t\t\t<p>Site criado com &#10084; para o curso de Web Scraping do Ocean.</p>\n\t\t</footer>\n\t</body>\n</html>'

# %%
soup_corretoras = BeautifulSoup(html_corretoras, 'html.parser')
soup_corretoras
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>Oceano de Aluguéis</title>
# <link href="reset.css" rel="stylesheet"/>
# <link href="style.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat&amp;display=swap" rel="stylesheet"/>
# </head>
# <body>
# <header>
# <div>
# <img src="imagens/oceano-logo.png"/>
# <h1>Oceano de Aluguéis</h1>
# <nav>
# <ul>
# <li><a href="results&amp;page=1.html">Resultados</a></li>
# <li><a href="corretoras.html">Corretoras</a></li>
# <li><a href="sobre.html">Sobre</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <main>
# <div class="contacts">
# <table>
# <thead>
# <tr>
# <th>Corretora</th>
# <th>Contatos</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Tubarão</td>
# <td>João Marinho - Fone:(XX)XXXX-XXXX</td>
# </tr>
# <tr>
# <td>Carangueijo</td>
# <td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebastião Costa - Fone:(XX)XXXX-XXXX</td>
# </tr>
# <tr>
# <td>Baleia Azul</td>
# <td>
# <ul>
# <li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>
# <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Enguia</td>
# <td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </main>
# <footer>
# <img src="imagens/oceano-logo-cinza.png"/>
# <p>Site criado com ❤ para o curso de Web Scraping do Ocean.</p>
# </footer>
# </body>
# </html>

# %% [markdown]
# ### 2) List of challenges from the 'About' page
#
# #### 2.1) Challenge 1: How about collecting the text 'About this site' to start?

# %%
soup_sobre.find('div', {'class': 'about'}).find('h2').get_text()
# Out:
# 'Sobre este site'

# %% [markdown]
# #### 2.2) Challenge 2: now extract the link contained in the word 'Ocean'.

# %%
soup_sobre.find('div', {'class': 'about'}).find('a').get('href')
# Out:
# 'http://www.oceanbrasil.com/'

# %% [markdown]
# #### 2.3) Challenge 3: Then collect all items from this list.

# %%
soup_sobre.find('div', {'class': 'about'}).find('ol').find_all('li')
# Out:
# [<li>Que tal coletar o texto <em>"Sobre este site"</em> para começar?</li>,
#  <li>Agora extraia o link contido na palavra <em>"Ocean"</em>.</li>,
#  <li>Em seguida, colete todos os itens desta lista.</li>,
#  <li>Por fim, colete apenas este último item da lista.</li>]

# %%
for item in soup_sobre.find('div', {'class': 'about'}).find('ol').find_all('li'):
    print(item.get_text())
# Out:
# Que tal coletar o texto "Sobre este site" para começar?
# Agora extraia o link contido na palavra "Ocean".
# Em seguida, colete todos os itens desta lista.
# Por fim, colete apenas este último item da lista.

# %% [markdown]
# #### 2.4) Challenge 4: Finally, collect only this last item on the list.

# %%
soup_sobre.find('div', {'class': 'about'}).find('ol').find_all('li')[-1].get_text()
# Out:
# 'Por fim, colete apenas este último item da lista.'

# %% [markdown]
# ### 3) Collecting the list of property search results

# %%
import pandas as pd

# %% [markdown]
# #### 3.1) Collecting only the first item in the list

# %%
soup_busca.find('div', {'class': 'ad-card'})
# Out:
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>

# %% [markdown]
# #### 3.1.1) Collecting the features

# %%
soup_busca.find('ul', {'class': 'features'})
# Out:
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>

# %%
soup_busca.find('ul', {'class': 'features'}).find_all('li')
# Out:
# [<li><img src="imagens/area.png"/> 100 m²</li>,
#  <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>,
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>,
#  <li><img src="imagens/parking.png"/> 2 vaga(s)</li>]

# %%
for caracteristica in soup_busca.find('ul', {'class': 'features'}).find_all('li'):
    print(caracteristica.get_text())
# Out:
#  100 m²
#  3 quarto(s)
#  2 banheiro(s)
#  2 vaga(s)

# %% [markdown]
# #### 3.1.2) Collecting the resources

# %%
soup_busca.find('ul', {'class': 'resources'})
# Out:
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>

# %%
soup_busca.find('ul', {'class': 'resources'}).find_all('li')
# Out:
# [<li>Mobiliado</li>,
#  <li>Portaria 24h</li>,
#  <li>Elevador</li>,
#  <li>Piscina</li>,
#  <li>Churrasqueira</li>,
#  <li>Salão de Festas</li>,
#  <li>Academia</li>,
#  <li>Playground</li>,
#  <li>Quadra poliesportiva</li>,
#  <li>Salão de jogos</li>,
#  <li>Aceita animais</li>]

# %%
for recurso in soup_busca.find('ul', {'class': 'resources'}).find_all('li'):
    print(recurso.get_text())
# Out:
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais

# %% [markdown]
# #### 3.1.3) Collecting all values ​​(rent, condominium and IPTU)

# %%
soup_busca.find('div', {'class': 'ad-card-price'})
# Out:
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>

# %%
soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')
# Out:
# [<p>Aluguel: R$ 4.000,00</p>,
#  <p>Condomínio: 500,00</p>,
#  <p>IPTU: R$ 100,00</p>,
#  <p>Corretora: Tubarão</p>]

# %%
soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')[:-1]
# Out:
# [<p>Aluguel: R$ 4.000,00</p>,
#  <p>Condomínio: 500,00</p>,
#  <p>IPTU: R$ 100,00</p>]

# %%
for precos in soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')[:-1]:
    print(precos.get_text())
# Out:
# Aluguel: R$ 4.000,00
# Condomínio: 500,00
# IPTU: R$ 100,00

# %% [markdown]
# #### 3.1.4) Collecting the broker

# %%
soup_busca.find('div', {'class': 'ad-card-price'})
# Out:
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>

# %%
soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')
# Out:
# [<p>Aluguel: R$ 4.000,00</p>,
#  <p>Condomínio: 500,00</p>,
#  <p>IPTU: R$ 100,00</p>,
#  <p>Corretora: Tubarão</p>]

# %%
soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')[-1]
# Out:
# <p>Corretora: Tubarão</p>

# %%
soup_busca.find('div', {'class': 'ad-card-price'}).find_all('p')[-1].get_text()
# Out:
# 'Corretora: Tubarão'

# %% [markdown]
# #### 3.1.5) Collecting the location

# %%
soup_busca.find('div', {'class': 'ad-card-info'})
# Out:
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>

# %%
soup_busca.find('div', {'class': 'ad-card-info'}).find('p')
# Out:
# <p>Localização: Oceano Pacífico</p>

# %%
soup_busca.find('div', {'class': 'ad-card-info'}).find('p').get_text()
# Out:
# 'Localização: Oceano Pacífico'

# %% [markdown]
# ### 3.2) Collecting all items from the first page

# %%
soup_busca.find('div', {'class': 'ad-card-list'})
# Out:
# <div class="ad-card-list">
# <p>21 resultados obtidos - Página 1</p>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-02.jpg"/>
# <div class="ad-card-info">
# <h2>Ótimo lugar para morar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Salão de Festas</li>
# <li>Quadra poliesportiva</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 2.000,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Carangueijo</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-03.jpg"/>
# <div class="ad-card-info">
# <h2>Belíssimo apartamento mobiliado</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 50 m²</li>
# <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# </ul>
# <p>Localização: Mar de Java</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.300,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-04.jpg"/>
# <div class="ad-card-info">
# <h2>Um cantinho todo seu</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.800,00</p>
# <p>Condomínio: 100,00</p>
# <p>IPTU: R$ 20,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-05.jpg"/>
# <div class="ad-card-info">
# <h2>Alugue já! Ótima oportunidade</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 120 m²</li>
# <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 3.800,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 200,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# </div>

# %%
soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'})
# Out:
# [<div class="ad-card">
#  <img class="apto-img" src="imagens/apto-01.jpg"/>
#  <div class="ad-card-info">
#  <h2>Lindo apartamento para alugar</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 100 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Elevador</li>
#  <li>Piscina</li>
#  <li>Churrasqueira</li>
#  <li>Salão de Festas</li>
#  <li>Academia</li>
#  <li>Playground</li>
#  <li>Quadra poliesportiva</li>
#  <li>Salão de jogos</li>
#  <li>Aceita animais</li>
#  </ul>
#  <p>Localização: Oceano Pacífico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 4.000,00</p>
#  <p>Condomínio: 500,00</p>
#  <p>IPTU: R$ 100,00</p>
#  <p>Corretora: Tubarão</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-02.jpg"/>
#  <div class="ad-card-info">
#  <h2>Ótimo lugar para morar</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 60 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Salão de Festas</li>
#  <li>Quadra poliesportiva</li>
#  </ul>
#  <p>Localização: Oceano Índico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 2.000,00</p>
#  <p>Condomínio: 200,00</p>
#  <p>IPTU: R$ 50,00</p>
#  <p>Corretora: Carangueijo</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-03.jpg"/>
#  <div class="ad-card-info">
#  <h2>Belíssimo apartamento mobiliado</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 50 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  </ul>
#  <p>Localização: Mar de Java</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 1.300,00</p>
#  <p>Condomínio: 200,00</p>
#  <p>IPTU: R$ 50,00</p>
#  <p>Corretora: Baleia Azul</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-04.jpg"/>
#  <div class="ad-card-info">
#  <h2>Um cantinho todo seu</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 60 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  </ul>
#  <p>Localização: Oceano Índico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 1.800,00</p>
#  <p>Condomínio: 100,00</p>
#  <p>IPTU: R$ 20,00</p>
#  <p>Corretora: Baleia Azul</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-05.jpg"/>
#  <div class="ad-card-info">
#  <h2>Alugue já! Ótima oportunidade</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 120 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Elevador</li>
#  <li>Piscina</li>
#  <li>Churrasqueira</li>
#  <li>Salão de Festas</li>
#  <li>Academia</li>
#  <li>Playground</li>
#  <li>Quadra poliesportiva</li>
#  <li>Salão de jogos</li>
#  <li>Aceita animais</li>
#  </ul>
#  <p>Localização: Oceano Pacífico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 3.800,00</p>
#  <p>Condomínio: 500,00</p>
#  <p>IPTU: R$ 200,00</p>
#  <p>Corretora: Tubarão</p>
#  </div>
#  </div>]

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    print(resultado)
    print('-------------')
# Out:
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# -------------
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-02.jpg"/>
# <div class="ad-card-info">
# <h2>Ótimo lugar para morar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Salão de Festas</li>
# <li>Quadra poliesportiva</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 2.000,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Carangueijo</p>
# </div>
# </div>
# -------------
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-03.jpg"/>
# <div class="ad-card-info">
# <h2>Belíssimo apartamento mobiliado</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 50 m²</li>
# <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# </ul>
# <p>Localização: Mar de Java</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.300,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# -------------
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-04.jpg"/>
# <div class="ad-card-info">
# <h2>Um cantinho todo seu</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.800,00</p>
# <p>Condomínio: 100,00</p>
# <p>IPTU: R$ 20,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# -------------
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-05.jpg"/>
# <div class="ad-card-info">
# <h2>Alugue já! Ótima oportunidade</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 120 m²</li>
# <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 3.800,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 200,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# -------------

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    print(caracteristicas)
    print('-------------')
# Out:
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# -------------
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# -------------
# <ul class="features">
# <li><img src="imagens/area.png"/> 50 m²</li>
# <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# -------------
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# -------------
# <ul class="features">
# <li><img src="imagens/area.png"/> 120 m²</li>
# <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# -------------

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    
    for caract in caracteristicas.find_all('li'):
        print(caract.get_text())
    
    print('-------------')
# Out:
#  100 m²
#  3 quarto(s)
#  2 banheiro(s)
#  2 vaga(s)
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# -------------
#  50 m²
#  1 quarto(s)
#  1 banheiro(s)
#  1 vaga(s)
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# -------------
#  120 m²
#  4 quarto(s)
#  3 banheiro(s)
#  2 vaga(s)
# -------------

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    recursos = resultado.find('ul', {'class': 'resources'})
    
    for caract in caracteristicas.find_all('li'):
        print(caract.get_text())
        
    for recur in recursos.find_all('li'):
        print(recur.get_text())
        
    print('-------------')
# Out:
#  100 m²
#  3 quarto(s)
#  2 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# Salão de Festas
# Quadra poliesportiva
# -------------
#  50 m²
#  1 quarto(s)
#  1 banheiro(s)
#  1 vaga(s)
# Mobiliado
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# -------------
#  120 m²
#  4 quarto(s)
#  3 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# -------------

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    recursos = resultado.find('ul', {'class': 'resources'})
    precos_corretora = resultado.find('div', {'class': 'ad-card-price'})
    
    for caract in caracteristicas.find_all('li'):
        print(caract.get_text())
        
    for recur in recursos.find_all('li'):
        print(recur.get_text())
        
    for prec_corr in precos_corretora.find_all('p'):
        print(prec_corr.get_text())
        
    print('-------------')
# Out:
#  100 m²
#  3 quarto(s)
#  2 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# Aluguel: R$ 4.000,00
# Condomínio: 500,00
# IPTU: R$ 100,00
# Corretora: Tubarão
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# Salão de Festas
# Quadra poliesportiva
# Aluguel: R$ 2.000,00
# Condomínio: 200,00
# IPTU: R$ 50,00
# Corretora: Carangueijo
# -------------
#  50 m²
#  1 quarto(s)
#  1 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Aluguel: R$ 1.300,00
# Condomínio: 200,00
# IPTU: R$ 50,00
# Corretora: Baleia Azul
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# Aluguel: R$ 1.800,00
# Condomínio: 100,00
# IPTU: R$ 20,00
# Corretora: Baleia Azul
# -------------
#  120 m²
#  4 quarto(s)
#  3 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# Aluguel: R$ 3.800,00
# Condomínio: 500,00
# IPTU: R$ 200,00
# Corretora: Tubarão
# -------------

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    recursos = resultado.find('ul', {'class': 'resources'})
    precos_corretora = resultado.find('div', {'class': 'ad-card-price'})
    localizacao = resultado.find('div', {'class': 'ad-card-info'}).find('p')
    
    for caract in caracteristicas.find_all('li'):
        print(caract.get_text())
        
    for recur in recursos.find_all('li'):
        print(recur.get_text())
        
    for prec_corr in precos_corretora.find_all('p'):
        print(prec_corr.get_text())
    
    print(localizacao.get_text())
        
    print('-------------')
# Out:
#  100 m²
#  3 quarto(s)
#  2 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# Aluguel: R$ 4.000,00
# Condomínio: 500,00
# IPTU: R$ 100,00
# Corretora: Tubarão
# Localização: Oceano Pacífico
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# Salão de Festas
# Quadra poliesportiva
# Aluguel: R$ 2.000,00
# Condomínio: 200,00
# IPTU: R$ 50,00
# Corretora: Carangueijo
# Localização: Oceano Índico
# -------------
#  50 m²
#  1 quarto(s)
#  1 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Aluguel: R$ 1.300,00
# Condomínio: 200,00
# IPTU: R$ 50,00
# Corretora: Baleia Azul
# Localização: Mar de Java
# -------------
#  60 m²
#  2 quarto(s)
#  2 banheiro(s)
#  1 vaga(s)
# Mobiliado
# Portaria 24h
# Aluguel: R$ 1.800,00
# Condomínio: 100,00
# IPTU: R$ 20,00
# Corretora: Baleia Azul
# Localização: Oceano Índico
# -------------
#  120 m²
#  4 quarto(s)
#  3 banheiro(s)
#  2 vaga(s)
# Mobiliado
# Portaria 24h
# Elevador
# Piscina
# Churrasqueira
# Salão de Festas
# Academia
# Playground
# Quadra poliesportiva
# Salão de jogos
# Aceita animais
# Aluguel: R$ 3.800,00
# Condomínio: 500,00
# IPTU: R$ 200,00
# Corretora: Tubarão
# Localização: Oceano Pacífico
# -------------

# %% [markdown]
# #### 3.2.1) Persisting the collected data in a DataFrame (attempt 1)

# %%
resutados_lista = []

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    recursos = resultado.find('ul', {'class': 'resources'})
    precos_corretora = resultado.find('div', {'class': 'ad-card-price'})
    localizacao = resultado.find('div', {'class': 'ad-card-info'}).find('p')
    
    resutado_dict = {}
    
    resutado_dict['área'] = caracteristicas.find_all('li')[0].get_text()
    resutado_dict['quartos'] = caracteristicas.find_all('li')[1].get_text()
    resutado_dict['banheiros'] = caracteristicas.find_all('li')[2].get_text()
    resutado_dict['vagas garagem'] = caracteristicas.find_all('li')[3].get_text()
    
    for recur in recursos.find_all('li'):
        resutado_dict[recur.get_text().lower()] = 'sim'
        
    resutado_dict['aluguel'] = precos_corretora.find_all('p')[0].get_text()
    resutado_dict['condomínio'] = precos_corretora.find_all('p')[1].get_text()
    resutado_dict['iptu'] = precos_corretora.find_all('p')[2].get_text()
    resutado_dict['corretora'] = precos_corretora.find_all('p')[3].get_text()
    
    resutado_dict['localizacao'] = localizacao.get_text()
    
    resutados_lista.append(resutado_dict)

# %%
resutados_lista
# Out:
# [{'área': ' 100 m²',
#   'quartos': ' 3 quarto(s)',
#   'banheiros': ' 2 banheiro(s)',
#   'vagas garagem': ' 2 vaga(s)',
#   'mobiliado': 'sim',
#   'portaria 24h': 'sim',
#   'elevador': 'sim',
#   'piscina': 'sim',
#   'churrasqueira': 'sim',
#   'salão de festas': 'sim',
#   'academia': 'sim',
#   'playground': 'sim',
#   'quadra poliesportiva': 'sim',
#   'salão de jogos': 'sim',
#   'aceita animais': 'sim',
#   'aluguel': 'Aluguel: R$ 4.000,00',
#   'condomínio': 'Condomínio: 500,00',
#   'iptu': 'IPTU: R$ 100,00',
#   'corretora': 'Corretora: Tubarão',
#   'localizacao': 'Localização: Oceano Pacífico'},
#  {'área': ' 60 m²',
#   'quartos': ' 2 quarto(s)',
#   'banheiros': ' 2 banheiro(s)',
#   'vagas garagem': ' 1 vaga(s)',
#   'mobiliado': 'sim',
#   'portaria 24h': 'sim',
#   'salão de festas': 'sim',
#   'quadra poliesportiva': 'sim',
#   'aluguel': 'Aluguel: R$ 2.000,00',
#   'condomínio': 'Condomínio: 200,00',
#   'iptu': 'IPTU: R$ 50,00',
#   'corretora': 'Corretora: Carangueijo',
#   'localizacao': 'Localização: Oceano Índico'},
#  {'área': ' 50 m²',
#   'quartos': ' 1 quarto(s)',
#   'banheiros': ' 1 banheiro(s)',
#   'vagas garagem': ' 1 vaga(s)',
#   'mobiliado': 'sim',
#   'aluguel': 'Aluguel: R$ 1.300,00',
#   'condomínio': 'Condomínio: 200,00',
#   'iptu': 'IPTU: R$ 50,00',
#   'corretora': 'Corretora: Baleia Azul',
#   'localizacao': 'Localização: Mar de Java'},
#  {'área': ' 60 m²',
#   'quartos': ' 2 quarto(s)',
#   'banheiros': ' 2 banheiro(s)',
#   'vagas garagem': ' 1 vaga(s)',
#   'mobiliado': 'sim',
#   'portaria 24h': 'sim',
#   'aluguel': 'Aluguel: R$ 1.800,00',
#   'condomínio': 'Condomínio: 100,00',
#   'iptu': 'IPTU: R$ 20,00',
#   'corretora': 'Corretora: Baleia Azul',
#   'localizacao': 'Localização: Oceano Índico'},
#  {'área': ' 120 m²',
#   'quartos': ' 4 quarto(s)',
#   'banheiros': ' 3 banheiro(s)',
#   'vagas garagem': ' 2 vaga(s)',
#   'mobiliado': 'sim',
#   'portaria 24h': 'sim',
#   'elevador': 'sim',
#   'piscina': 'sim',
#   'churrasqueira': 'sim',
#   'salão de festas': 'sim',
#   'academia': 'sim',
#   'playground': 'sim',
#   'quadra poliesportiva': 'sim',
#   'salão de jogos': 'sim',
#   'aceita animais': 'sim',
#   'aluguel': 'Aluguel: R$ 3.800,00',
#   'condomínio': 'Condomínio: 500,00',
#   'iptu': 'IPTU: R$ 200,00',
#   'corretora': 'Corretora: Tubarão',
#   'localizacao': 'Localização: Oceano Pacífico'}]

# %%
resultados_df = pd.DataFrame(resutados_lista)

# %%
resultados_df
# Out:
#       área       quartos       banheiros vagas garagem mobiliado portaria 24h  \
# 0   100 m²   3 quarto(s)   2 banheiro(s)     2 vaga(s)       sim          sim
# 1    60 m²   2 quarto(s)   2 banheiro(s)     1 vaga(s)       sim          sim
# 2    50 m²   1 quarto(s)   1 banheiro(s)     1 vaga(s)       sim          NaN
# 3    60 m²   2 quarto(s)   2 banheiro(s)     1 vaga(s)       sim          sim
# 4   120 m²   4 quarto(s)   3 banheiro(s)     2 vaga(s)       sim          sim
#
#   elevador piscina churrasqueira salão de festas academia playground  \
# 0      sim     sim           sim             sim      sim        sim
# 1      NaN     NaN           NaN             sim      NaN        NaN
# 2      NaN     NaN           NaN             NaN      NaN        NaN
# 3      NaN     NaN           NaN             NaN      NaN        NaN
# 4      sim     sim           sim             sim      sim        sim
#
#   quadra poliesportiva salão de jogos aceita animais               aluguel  \
# 0                  sim            sim            sim  Aluguel: R$ 4.000,00
# 1                  sim            NaN            NaN  Aluguel: R$ 2.000,00
# 2                  NaN            NaN            NaN  Aluguel: R$ 1.300,00
# 3                  NaN            NaN            NaN  Aluguel: R$ 1.800,00
# 4                  sim            sim            sim  Aluguel: R$ 3.800,00
#
#            condomínio             iptu               corretora  \
# 0  Condomínio: 500,00  IPTU: R$ 100,00      Corretora: Tubarão
# 1  Condomínio: 200,00   IPTU: R$ 50,00  Corretora: Carangueijo
# 2  Condomínio: 200,00   IPTU: R$ 50,00  Corretora: Baleia Azul
# 3  Condomínio: 100,00   IPTU: R$ 20,00  Corretora: Baleia Azul
# 4  Condomínio: 500,00  IPTU: R$ 200,00      Corretora: Tubarão
#
#                     localizacao
# 0  Localização: Oceano Pacífico
# 1    Localização: Oceano Índico
# 2      Localização: Mar de Java
# 3    Localização: Oceano Índico
# 4  Localização: Oceano Pacífico

# %%
resultados_df.dtypes
# Out:
# área                    object
# quartos                 object
# banheiros               object
# vagas garagem           object
# mobiliado               object
# portaria 24h            object
# elevador                object
# piscina                 object
# churrasqueira           object
# salão de festas         object
# academia                object
# playground              object
# quadra poliesportiva    object
# salão de jogos          object
# aceita animais          object
# aluguel                 object
# condomínio              object
# iptu                    object
# corretora               object
# localizacao             object
# dtype: object

# %% [markdown]
# #### 3.2.2) Persisting the collected data in a DataFrame (attempt 2)

# %%
resutados_lista = []

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    caracteristicas = resultado.find('ul', {'class': 'features'})
    recursos = resultado.find('ul', {'class': 'resources'})
    precos_corretora = resultado.find('div', {'class': 'ad-card-price'})
    localizacao = resultado.find('div', {'class': 'ad-card-info'}).find('p')
    
    resutado_dict = {}
    
    resutado_dict['área'] = int(caracteristicas.find_all('li')[0].get_text().replace(' ','').replace('m²',''))
    resutado_dict['quartos'] = int(caracteristicas.find_all('li')[1].get_text().replace(' ','').replace('quarto(s)',''))
    resutado_dict['banheiros'] = int(caracteristicas.find_all('li')[2].get_text().replace(' ','').replace('banheiro(s)',''))
    resutado_dict['vagas garagem'] = int(caracteristicas.find_all('li')[3].get_text().replace(' ','').replace('vaga(s)',''))
    
    for recur in recursos.find_all('li'):
        resutado_dict[recur.get_text().lower()] = 'sim'
        
    resutado_dict['aluguel'] = float(precos_corretora.find_all('p')[0].get_text().replace('Aluguel: R$ ','').replace('.','').replace(',','.'))
    resutado_dict['condomínio'] = float(precos_corretora.find_all('p')[1].get_text().replace('Condomínio: ','').replace('.','').replace(',','.'))
    resutado_dict['iptu'] = float(precos_corretora.find_all('p')[2].get_text().replace('IPTU: R$ ','').replace('.','').replace(',','.'))
    
    resutado_dict['corretora'] = precos_corretora.find_all('p')[3].get_text().replace('Corretora: ','')
    
    resutado_dict['localizacao'] = localizacao.get_text().replace('Localização: ','')
    
    resutados_lista.append(resutado_dict)

# %%
resultados_df = pd.DataFrame(resutados_lista)
resultados_df
# Out:
#    área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 0   100        3          2              2       sim          sim      sim
# 1    60        2          2              1       sim          sim      NaN
# 2    50        1          1              1       sim          NaN      NaN
# 3    60        2          2              1       sim          sim      NaN
# 4   120        4          3              2       sim          sim      sim
#
#   piscina churrasqueira salão de festas academia playground  \
# 0     sim           sim             sim      sim        sim
# 1     NaN           NaN             sim      NaN        NaN
# 2     NaN           NaN             NaN      NaN        NaN
# 3     NaN           NaN             NaN      NaN        NaN
# 4     sim           sim             sim      sim        sim
#
#   quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 0                  sim            sim            sim   4000.0       500.0
# 1                  sim            NaN            NaN   2000.0       200.0
# 2                  NaN            NaN            NaN   1300.0       200.0
# 3                  NaN            NaN            NaN   1800.0       100.0
# 4                  sim            sim            sim   3800.0       500.0
#
#     iptu    corretora      localizacao
# 0  100.0      Tubarão  Oceano Pacífico
# 1   50.0  Carangueijo    Oceano Índico
# 2   50.0  Baleia Azul      Mar de Java
# 3   20.0  Baleia Azul    Oceano Índico
# 4  200.0      Tubarão  Oceano Pacífico

# %%
resultados_df = resultados_df.fillna(value='não')
resultados_df
# Out:
#    área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 0   100        3          2              2       sim          sim      sim
# 1    60        2          2              1       sim          sim      não
# 2    50        1          1              1       sim          não      não
# 3    60        2          2              1       sim          sim      não
# 4   120        4          3              2       sim          sim      sim
#
#   piscina churrasqueira salão de festas academia playground  \
# 0     sim           sim             sim      sim        sim
# 1     não           não             sim      não        não
# 2     não           não             não      não        não
# 3     não           não             não      não        não
# 4     sim           sim             sim      sim        sim
#
#   quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 0                  sim            sim            sim   4000.0       500.0
# 1                  sim            não            não   2000.0       200.0
# 2                  não            não            não   1300.0       200.0
# 3                  não            não            não   1800.0       100.0
# 4                  sim            sim            sim   3800.0       500.0
#
#     iptu    corretora      localizacao
# 0  100.0      Tubarão  Oceano Pacífico
# 1   50.0  Carangueijo    Oceano Índico
# 2   50.0  Baleia Azul      Mar de Java
# 3   20.0  Baleia Azul    Oceano Índico
# 4  200.0      Tubarão  Oceano Pacífico

# %%
resultados_df.dtypes
# Out:
# área                      int64
# quartos                   int64
# banheiros                 int64
# vagas garagem             int64
# mobiliado                object
# portaria 24h             object
# elevador                 object
# piscina                  object
# churrasqueira            object
# salão de festas          object
# academia                 object
# playground               object
# quadra poliesportiva     object
# salão de jogos           object
# aceita animais           object
# aluguel                 float64
# condomínio              float64
# iptu                    float64
# corretora                object
# localizacao              object
# dtype: object

# %% [markdown]
# ### 3.3) Collecting the images from the first page
#
# #### 3.3.1) Creating a directory for images

# %%
import os

# %%
os.makedirs('imagens')

# %% [markdown]
# #### 3.3.2) Getting the images

# %%
soup_busca.find('div', {'class': 'ad-card-list'})
# Out:
# <div class="ad-card-list">
# <p>21 resultados obtidos - Página 1</p>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <div class="ad-card-info">
# <h2>Lindo apartamento para alugar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 100 m²</li>
# <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 4.000,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 100,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-02.jpg"/>
# <div class="ad-card-info">
# <h2>Ótimo lugar para morar</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Salão de Festas</li>
# <li>Quadra poliesportiva</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 2.000,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Carangueijo</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-03.jpg"/>
# <div class="ad-card-info">
# <h2>Belíssimo apartamento mobiliado</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 50 m²</li>
# <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# </ul>
# <p>Localização: Mar de Java</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.300,00</p>
# <p>Condomínio: 200,00</p>
# <p>IPTU: R$ 50,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-04.jpg"/>
# <div class="ad-card-info">
# <h2>Um cantinho todo seu</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 60 m²</li>
# <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# </ul>
# <p>Localização: Oceano Índico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 1.800,00</p>
# <p>Condomínio: 100,00</p>
# <p>IPTU: R$ 20,00</p>
# <p>Corretora: Baleia Azul</p>
# </div>
# </div>
# <div class="ad-card">
# <img class="apto-img" src="imagens/apto-05.jpg"/>
# <div class="ad-card-info">
# <h2>Alugue já! Ótima oportunidade</h2>
# <ul class="features">
# <li><img src="imagens/area.png"/> 120 m²</li>
# <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
# <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
# <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
# </ul>
# <ul class="resources">
# <li>Mobiliado</li>
# <li>Portaria 24h</li>
# <li>Elevador</li>
# <li>Piscina</li>
# <li>Churrasqueira</li>
# <li>Salão de Festas</li>
# <li>Academia</li>
# <li>Playground</li>
# <li>Quadra poliesportiva</li>
# <li>Salão de jogos</li>
# <li>Aceita animais</li>
# </ul>
# <p>Localização: Oceano Pacífico</p>
# </div>
# <div class="ad-card-price">
# <p>Aluguel: R$ 3.800,00</p>
# <p>Condomínio: 500,00</p>
# <p>IPTU: R$ 200,00</p>
# <p>Corretora: Tubarão</p>
# </div>
# </div>
# </div>

# %%
soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'})
# Out:
# [<div class="ad-card">
#  <img class="apto-img" src="imagens/apto-01.jpg"/>
#  <div class="ad-card-info">
#  <h2>Lindo apartamento para alugar</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 100 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 3 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Elevador</li>
#  <li>Piscina</li>
#  <li>Churrasqueira</li>
#  <li>Salão de Festas</li>
#  <li>Academia</li>
#  <li>Playground</li>
#  <li>Quadra poliesportiva</li>
#  <li>Salão de jogos</li>
#  <li>Aceita animais</li>
#  </ul>
#  <p>Localização: Oceano Pacífico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 4.000,00</p>
#  <p>Condomínio: 500,00</p>
#  <p>IPTU: R$ 100,00</p>
#  <p>Corretora: Tubarão</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-02.jpg"/>
#  <div class="ad-card-info">
#  <h2>Ótimo lugar para morar</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 60 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Salão de Festas</li>
#  <li>Quadra poliesportiva</li>
#  </ul>
#  <p>Localização: Oceano Índico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 2.000,00</p>
#  <p>Condomínio: 200,00</p>
#  <p>IPTU: R$ 50,00</p>
#  <p>Corretora: Carangueijo</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-03.jpg"/>
#  <div class="ad-card-info">
#  <h2>Belíssimo apartamento mobiliado</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 50 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 1 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 1 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  </ul>
#  <p>Localização: Mar de Java</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 1.300,00</p>
#  <p>Condomínio: 200,00</p>
#  <p>IPTU: R$ 50,00</p>
#  <p>Corretora: Baleia Azul</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-04.jpg"/>
#  <div class="ad-card-info">
#  <h2>Um cantinho todo seu</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 60 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 2 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 2 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 1 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  </ul>
#  <p>Localização: Oceano Índico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 1.800,00</p>
#  <p>Condomínio: 100,00</p>
#  <p>IPTU: R$ 20,00</p>
#  <p>Corretora: Baleia Azul</p>
#  </div>
#  </div>,
#  <div class="ad-card">
#  <img class="apto-img" src="imagens/apto-05.jpg"/>
#  <div class="ad-card-info">
#  <h2>Alugue já! Ótima oportunidade</h2>
#  <ul class="features">
#  <li><img src="imagens/area.png"/> 120 m²</li>
#  <li><img src="imagens/bedrooms.png"/> 4 quarto(s)</li>
#  <li><img src="imagens/toilet.png"/> 3 banheiro(s)</li>
#  <li><img src="imagens/parking.png"/> 2 vaga(s)</li>
#  </ul>
#  <ul class="resources">
#  <li>Mobiliado</li>
#  <li>Portaria 24h</li>
#  <li>Elevador</li>
#  <li>Piscina</li>
#  <li>Churrasqueira</li>
#  <li>Salão de Festas</li>
#  <li>Academia</li>
#  <li>Playground</li>
#  <li>Quadra poliesportiva</li>
#  <li>Salão de jogos</li>
#  <li>Aceita animais</li>
#  </ul>
#  <p>Localização: Oceano Pacífico</p>
#  </div>
#  <div class="ad-card-price">
#  <p>Aluguel: R$ 3.800,00</p>
#  <p>Condomínio: 500,00</p>
#  <p>IPTU: R$ 200,00</p>
#  <p>Corretora: Tubarão</p>
#  </div>
#  </div>]

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    print(resultado.img)
# Out:
# <img class="apto-img" src="imagens/apto-01.jpg"/>
# <img class="apto-img" src="imagens/apto-02.jpg"/>
# <img class="apto-img" src="imagens/apto-03.jpg"/>
# <img class="apto-img" src="imagens/apto-04.jpg"/>
# <img class="apto-img" src="imagens/apto-05.jpg"/>

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    print(resultado.img.get('src'))
# Out:
# imagens/apto-01.jpg
# imagens/apto-02.jpg
# imagens/apto-03.jpg
# imagens/apto-04.jpg
# imagens/apto-05.jpg

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    print(resultado.img.get('src').replace('imagens/',''))
# Out:
# apto-01.jpg
# apto-02.jpg
# apto-03.jpg
# apto-04.jpg
# apto-05.jpg

# %%
endereco = 'https://ocean-web-scraping.herokuapp.com/'

for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    print(endereco + resultado.img.get('src'))
# Out:
# https://ocean-web-scraping.herokuapp.com/imagens/apto-01.jpg
# https://ocean-web-scraping.herokuapp.com/imagens/apto-02.jpg
# https://ocean-web-scraping.herokuapp.com/imagens/apto-03.jpg
# https://ocean-web-scraping.herokuapp.com/imagens/apto-04.jpg
# https://ocean-web-scraping.herokuapp.com/imagens/apto-05.jpg

# %%
from urllib.request import urlretrieve

# %%
for resultado in soup_busca.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
    endereco_imagem = endereco + resultado.img.get('src')
    nome_imagem = resultado.img.get('src').replace('imagens/','')
    
    urlretrieve(endereco_imagem, 'C:/Users/sub13/Downloads/results/imagens/' + nome_imagem)

# %% [markdown]
# #### 3.3.3) Compressing all images for later download

# %%
from zipfile import ZipFile

# %%
with ZipFile('imagens.zip', 'w') as zf:
    for pasta_principal, sub_pastas, arquivos in os.walk('C:/Users/sub13/Downloads/results/imagens/'):
        for arquivo in arquivos:
            pasta = os.path.join(pasta_principal, arquivo)
            zf.write(pasta)

# %% [markdown]
# ### 3.4) What if I want to collect all search results for properties?
#
# #### 3.4.1) General data

# %%
resutados_lista = []

# %%
for i in range(1,6):
    url_busca_todos = 'https://ocean-web-scraping.herokuapp.com/results&page=' + str(i) + '.html'
    print(url_busca_todos)
    response_busca_todos = urlopen(url_busca_todos)
    html_busca_todos = response_busca_todos.read()
    soup_busca_todos = BeautifulSoup(html_busca_todos, 'html.parser')
    
    for resultado in soup_busca_todos.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
        caracteristicas = resultado.find('ul', {'class': 'features'})
        recursos = resultado.find('ul', {'class': 'resources'})
        precos_corretora = resultado.find('div', {'class': 'ad-card-price'})
        localizacao = resultado.find('div', {'class': 'ad-card-info'}).find('p')

        resutado_dict = {}

        resutado_dict['área'] = int(caracteristicas.find_all('li')[0].get_text().replace(' ','').replace('m²',''))
        resutado_dict['quartos'] = int(caracteristicas.find_all('li')[1].get_text().replace(' ','').replace('quarto(s)',''))
        resutado_dict['banheiros'] = int(caracteristicas.find_all('li')[2].get_text().replace(' ','').replace('banheiro(s)',''))
        resutado_dict['vagas garagem'] = int(caracteristicas.find_all('li')[3].get_text().replace(' ','').replace('vaga(s)',''))

        for recur in recursos.find_all('li'):
            resutado_dict[recur.get_text().lower()] = 'sim'

        resutado_dict['aluguel'] = float(precos_corretora.find_all('p')[0].get_text().replace('Aluguel: R$ ','').replace('.','').replace(',','.'))
        resutado_dict['condomínio'] = float(precos_corretora.find_all('p')[1].get_text().replace('Condomínio: ','').replace('.','').replace(',','.'))
        resutado_dict['iptu'] = float(precos_corretora.find_all('p')[2].get_text().replace('IPTU: R$ ','').replace('.','').replace(',','.'))
        resutado_dict['corretora'] = precos_corretora.find_all('p')[3].get_text().replace('Corretora: ','')

        resutado_dict['localizacao'] = localizacao.get_text().replace('Localização: ','')

        resutados_lista.append(resutado_dict)
# Out:
# https://ocean-web-scraping.herokuapp.com/results&page=1.html
# https://ocean-web-scraping.herokuapp.com/results&page=2.html
# https://ocean-web-scraping.herokuapp.com/results&page=3.html
# https://ocean-web-scraping.herokuapp.com/results&page=4.html
# https://ocean-web-scraping.herokuapp.com/results&page=5.html

# %%
resultados_df = pd.DataFrame(resutados_lista)
resultados_df = resultados_df.fillna(value='não')
resultados_df
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 0    100        3          2              2       sim          sim      sim
# 1     60        2          2              1       sim          sim      não
# 2     50        1          1              1       sim          não      não
# 3     60        2          2              1       sim          sim      não
# 4    120        4          3              2       sim          sim      sim
# 5     40        1          1              0       não          sim      não
# 6     60        2          2              0       não          sim      não
# 7     60        2          1              1       sim          sim      não
# 8     60        2          2              1       sim          sim      não
# 9    100        3          3              1       sim          sim      não
# 10   100        2          2              1       sim          sim      sim
# 11    50        2          1              0       sim          sim      não
# 12    80        2          2              1       sim          sim      sim
# 13    70        2          2              1       sim          sim      não
# 14    60        2          1              1       sim          sim      não
# 15   100        3          3              2       sim          sim      sim
# 16    80        2          2              2       sim          sim      não
# 17    50        1          1              1       sim          não      não
# 18    70        2          2              1       sim          sim      não
# 19    70        2          2              1       sim          sim      não
# 20    40        1          1              0       não          não      sim
#
#    piscina churrasqueira salão de festas academia playground  \
# 0      sim           sim             sim      sim        sim
# 1      não           não             sim      não        não
# 2      não           não             não      não        não
# 3      não           não             não      não        não
# 4      sim           sim             sim      sim        sim
# 5      não           não             não      não        não
# 6      não           não             sim      não        não
# 7      sim           não             sim      não        não
# 8      não           não             não      não        não
# 9      sim           não             sim      sim        não
# 10     sim           não             sim      sim        não
# 11     não           não             não      não        não
# 12     sim           não             não      não        não
# 13     não           não             não      não        não
# 14     não           não             não      não        não
# 15     sim           sim             sim      sim        sim
# 16     não           não             sim      não        não
# 17     não           não             não      não        não
# 18     não           não             sim      não        não
# 19     não           não             sim      não        não
# 20     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 0                   sim            sim            sim   4000.0       500.0
# 1                   sim            não            não   2000.0       200.0
# 2                   não            não            não   1300.0       200.0
# 3                   não            não            não   1800.0       100.0
# 4                   sim            sim            sim   3800.0       500.0
# 5                   não            não            não    950.0        50.0
# 6                   sim            não            não   1100.0       100.0
# 7                   sim            não            não   1850.0       100.0
# 8                   não            não            não   1800.0       150.0
# 9                   sim            não            sim   3000.0       250.0
# 10                  não            não            sim   2800.0       220.0
# 11                  não            não            não   1300.0       100.0
# 12                  não            não            sim   1750.0       150.0
# 13                  não            não            não   1650.0       120.0
# 14                  não            não            sim   1250.0       100.0
# 15                  sim            sim            sim   3350.0       100.0
# 16                  sim            não            sim   2150.0       180.0
# 17                  não            não            não   1080.0       100.0
# 18                  sim            não            sim   2180.0       120.0
# 19                  não            não            sim   1900.0       100.0
# 20                  não            não            não    990.0        50.0
#
#      iptu    corretora       localizacao
# 0   100.0      Tubarão   Oceano Pacífico
# 1    50.0  Carangueijo     Oceano Índico
# 2    50.0  Baleia Azul       Mar de Java
# 3    20.0  Baleia Azul     Oceano Índico
# 4   200.0      Tubarão   Oceano Pacífico
# 5    10.0       Enguia  Mar Mediterrâneo
# 6    50.0       Enguia       Mar de Java
# 7    50.0  Carangueijo     Oceano Índico
# 8    50.0  Carangueijo     Oceano Índico
# 9    50.0      Tubarão   Oceano Pacífico
# 10   80.0      Tubarão  Oceano Atlântico
# 11   80.0       Enguia       Mar de Java
# 12   50.0  Baleia Azul       Mar de Java
# 13   20.0  Carangueijo  Oceano Atlântico
# 14   80.0       Enguia  Mar Mediterrâneo
# 15   50.0      Tubarão   Oceano Pacífico
# 16   20.0  Baleia Azul     Oceano Índico
# 17   20.0       Enguia  Mar Mediterrâneo
# 18   40.0  Carangueijo   Oceano Pacífico
# 19   20.0  Baleia Azul       Mar de Java
# 20   10.0       Enguia  Mar Mediterrâneo

# %% [markdown]
# #### Saving the entire database

# %%
resultados_df.to_csv('C:/Users/sub13/Downloads/results/resultadata.csv', sep = ';', index = False, encoding = 'utf-8')

# %% [markdown]
# #### 3.4.2) Images

# %%
for i in range(1,6):
    url_busca_todos = 'https://ocean-web-scraping.herokuapp.com/results&page=' + str(i) + '.html'
    print(url_busca_todos)
    response_busca_todos = urlopen(url_busca_todos)
    html_busca_todos = response_busca_todos.read()
    soup_busca_todos = BeautifulSoup(html_busca_todos, 'html.parser')
    
    endereco = 'https://ocean-web-scraping.herokuapp.com/'
    
    for resultado in soup_busca_todos.find('div', {'class': 'ad-card-list'}).find_all('div', {'class': 'ad-card'}):
        endereco_imagem = endereco + resultado.img.get('src')
        nome_imagem = resultado.img.get('src').replace('imagens/','')
    
        urlretrieve(endereco_imagem, 'C:/Users/sub13/Downloads/results/images1/' + nome_imagem)
# Out:
# https://ocean-web-scraping.herokuapp.com/results&page=1.html
# https://ocean-web-scraping.herokuapp.com/results&page=2.html
# https://ocean-web-scraping.herokuapp.com/results&page=3.html
# https://ocean-web-scraping.herokuapp.com/results&page=4.html
# https://ocean-web-scraping.herokuapp.com/results&page=5.html

# %%
with ZipFile('imagens.zip', 'w') as zf:
    for pasta_principal, sub_pastas, arquivos in os.walk('C:/Users/sub13/Downloads/results/images1/'):
        for arquivo in arquivos:
            pasta = os.path.join(pasta_principal, arquivo)
            zf.write(pasta)

# %% [markdown]
# ### 4) Collecting the contact list of brokers

# %%
lista_corretoras = []
lista_nomes = []
lista_contatos = []
contatos_corretoras_dict = {}

# %% [markdown]
# #### 4.1) Collecting data from the broker 'Tubarão'

# %%
soup_corretoras.find('tbody')
# Out:
# <tbody>
# <tr>
# <td>Tubarão</td>
# <td>João Marinho - Fone:(XX)XXXX-XXXX</td>
# </tr>
# <tr>
# <td>Carangueijo</td>
# <td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebastião Costa - Fone:(XX)XXXX-XXXX</td>
# </tr>
# <tr>
# <td>Baleia Azul</td>
# <td>
# <ul>
# <li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>
# <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Enguia</td>
# <td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>
# </tr>
# </tbody>

# %%
soup_corretoras.find('tbody').find_all('tr')
# Out:
# [<tr>
#  <td>Tubarão</td>
#  <td>João Marinho - Fone:(XX)XXXX-XXXX</td>
#  </tr>,
#  <tr>
#  <td>Carangueijo</td>
#  <td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebastião Costa - Fone:(XX)XXXX-XXXX</td>
#  </tr>,
#  <tr>
#  <td>Baleia Azul</td>
#  <td>
#  <ul>
#  <li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>
#  <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>
#  </ul>
#  </td>
#  </tr>,
#  <tr>
#  <td>Enguia</td>
#  <td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>
#  </tr>]

# %%
soup_corretoras.find('tbody').find_all('tr')[0]
# Out:
# <tr>
# <td>Tubarão</td>
# <td>João Marinho - Fone:(XX)XXXX-XXXX</td>
# </tr>

# %%
soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')
# Out:
# [<td>Tubarão</td>, <td>João Marinho - Fone:(XX)XXXX-XXXX</td>]

# %%
print('Corretora: ', soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[0].get_text())
print('Contatos: ', soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[1].get_text())
# Out:
# Corretora:  Tubarão
# Contatos:  João Marinho - Fone:(XX)XXXX-XXXX

# %%
soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[1].get_text().split(' - Fone:')
# Out:
# ['João Marinho', '(XX)XXXX-XXXX']

# %%
print('Corretora: ', soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[0].get_text())

contato = soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[1].get_text().split(' - Fone:')
print('Nome: ', contato[0])
print('Telefone: ', contato[1])
# Out:
# Corretora:  Tubarão
# Nome:  João Marinho
# Telefone:  (XX)XXXX-XXXX

# %% [markdown]
# #### Saving data in lists

# %%
lista_corretoras.append(soup_corretoras.find('tbody').find_all('tr')[0].find_all('td')[0].get_text())
lista_nomes.append(contato[0])
lista_contatos.append(contato[1])

# %%
lista_corretoras, lista_nomes, lista_contatos
# Out:
# (['Tubarão'], ['João Marinho'], ['(XX)XXXX-XXXX'])

# %% [markdown]
# ### 4.2) Collecting data from the broker 'Carangueijo'

# %%
soup_corretoras.find('tbody').find_all('tr')[1]
# Out:
# <tr>
# <td>Carangueijo</td>
# <td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebastião Costa - Fone:(XX)XXXX-XXXX</td>
# </tr>

# %%
soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')
# Out:
# [<td>Carangueijo</td>,
#  <td>Ana Sirigueijo - Fone:(XX)XXXX-XXXX; Sebastião Costa - Fone:(XX)XXXX-XXXX</td>]

# %% [markdown]
# #### Problem applying the same solution as the broker 'Tubarão'

# %%
soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[1].get_text().split(' - Fone:')
# Out:
# ['Ana Sirigueijo', '(XX)XXXX-XXXX; Sebastião Costa', '(XX)XXXX-XXXX']

# %% [markdown]
# #### solving the problem

# %%
soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[1].get_text().split('; ')
# Out:
# ['Ana Sirigueijo - Fone:(XX)XXXX-XXXX', 'Sebastião Costa - Fone:(XX)XXXX-XXXX']

# %%
for item in soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[1].get_text().split('; '):
    print(item.split(' - Fone:'))
# Out:
# ['Ana Sirigueijo', '(XX)XXXX-XXXX']
# ['Sebastião Costa', '(XX)XXXX-XXXX']

# %%
print('Corretora: ', soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[0].get_text())

contatos = soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[1].get_text().split('; ')

for contato in contatos:
    contato = contato.split(' - Fone:')
    print('Nome: ', contato[0])
    print('Telefone: ', contato[1])
# Out:
# Corretora:  Carangueijo
# Nome:  Ana Sirigueijo
# Telefone:  (XX)XXXX-XXXX
# Nome:  Sebastião Costa
# Telefone:  (XX)XXXX-XXXX

# %% [markdown]
# #### Saving data in lists

# %%
contatos = soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[1].get_text().split('; ')

for contato in contatos:
    lista_corretoras.append(soup_corretoras.find('tbody').find_all('tr')[1].find_all('td')[0].get_text())
    
    contato = contato.split(' - Fone:')
    
    lista_nomes.append(contato[0])
    lista_contatos.append(contato[1])

# %%
lista_corretoras, lista_nomes, lista_contatos
# Out:
# (['Tubarão', 'Carangueijo', 'Carangueijo'],
#  ['João Marinho', 'Ana Sirigueijo', 'Sebastião Costa'],
#  ['(XX)XXXX-XXXX', '(XX)XXXX-XXXX', '(XX)XXXX-XXXX'])

# %% [markdown]
# #### 4.3) Collecting data from the 'Blue Whale' broker

# %%
soup_corretoras.find('tbody').find_all('tr')[2]
# Out:
# <tr>
# <td>Baleia Azul</td>
# <td>
# <ul>
# <li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>
# <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>
# </ul>
# </td>
# </tr>

# %%
soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')
# Out:
# [<td>Baleia Azul</td>,
#  <td>
#  <ul>
#  <li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>
#  <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>
#  </ul>
#  </td>]

# %%
soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')[1].find_all('li')
# Out:
# [<li>Alina Ferreira - Fone:(XX)XXXX-XXXX</li>,
#  <li>Jorge Matheus - Fone:(XX)XXXX-XXXX</li>]

# %%
print('Corretora: ', soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')[0].get_text())

contatos = soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')[1].find_all('li')

for contato in contatos:
    contato = contato.get_text().split(' - Fone:')
    print('Nome: ', contato[0])
    print('Telefone: ', contato[1])
# Out:
# Corretora:  Baleia Azul
# Nome:  Alina Ferreira
# Telefone:  (XX)XXXX-XXXX
# Nome:  Jorge Matheus
# Telefone:  (XX)XXXX-XXXX

# %% [markdown]
# #### Saving data in lists

# %%
contatos = soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')[1].find_all('li')

for contato in contatos:
    lista_corretoras.append(soup_corretoras.find('tbody').find_all('tr')[2].find_all('td')[0].get_text())
    
    contato = contato.get_text().split(' - Fone:')
    
    lista_nomes.append(contato[0])
    lista_contatos.append(contato[1])

# %%
lista_corretoras, lista_nomes, lista_contatos
# Out:
# (['Tubarão', 'Carangueijo', 'Carangueijo', 'Baleia Azul', 'Baleia Azul'],
#  ['João Marinho',
#   'Ana Sirigueijo',
#   'Sebastião Costa',
#   'Alina Ferreira',
#   'Jorge Matheus'],
#  ['(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX'])

# %% [markdown]
# ### 4.4) Collecting data from the broker 'Eel'

# %%
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.5.1-py3-none-any.whl (12.0 MB)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\sub13\anaconda3\lib\site-packages (from tabula-py) (1.4.2)
# Requirement already satisfied: numpy in c:\users\sub13\anaconda3\lib\site-packages (from tabula-py) (1.21.5)
# Collecting distro
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sub13\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sub13\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sub13\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.8.0 tabula-py-2.5.1

# %%
import tabula

# %%
pip list
# Out:
# Package                       VersionNote: you may need to restart the kernel to use updated packages.
#
# ----------------------------- --------------------
# absl-py                       1.2.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.2.0
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-generator               1.10
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# blis                          0.7.8
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# cachetools                    4.2.2
# catalogue                     2.0.8
# catboost                      1.1
# certifi                       2022.6.15
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# comtypes                      1.1.10
# conda                         4.14.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.5
# conda-token                   0.3.0
# conda-verify                  3.4.2
# confection                    0.0.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  38.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# DateTime                      4.5
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.5.1
# distributed                   2022.2.1
# distro                        1.8.0
# docopt                        0.6.2
# docutils                      0.17.1
# docx2txt                      0.8
# echo                          0.5
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# etils                         0.7.1
# exceptiongroup                1.0.0rc9
# executing                     0.8.3
# Faker                         14.1.0
# fast-histogram                0.9
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# gensim                        4.1.2
# glob2                         0.7
# glue-core                     1.0.1
# glue-vispy-viewers            0.12.2
# glueviz                       1.0.0
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# graphviz                      0.20.1
# greenlet                      1.1.1
# grpcio                        1.42.0
# gTTS                          2.2.4
# h11                           0.14.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# html5lib                      1.1
# htmlmin                       0.1.12
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# ImageHash                     4.2.1
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.11.3
# importlib-resources           5.9.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipdb                          0.13.9
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# kafka                         1.3.5
# kafka-python                  2.0.2
# keyring                       23.4.0
# kiwisolver                    1.3.2
# langcodes                     3.3.0
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Markdown                      3.3.4
# MarkupSafe                    2.1.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# MechanicalSoup                1.2.0
# menuinst                      1.4.18
# missingno                     0.5.1
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpl-scatter-density           0.7
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.1.0
# multimethod                   1.8
# multipledispatch              0.6.0
# munkres                       1.1.4
# murmurhash                    1.0.8
# mypy-extensions               0.4.3
# mysql-connector               2.2.9
# mysql-connector-python        8.0.30
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# olefile                       0.46
# opencv-python                 4.6.0.66
# openpyxl                      3.0.9
# outcome                       1.2.0
# packaging                     21.3
# pandas                        1.4.2
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# pathspec                      0.7.0
# pathy                         0.6.2
# patsy                         0.5.2
# pdfminer.six                  20220524
# pep8                          1.7.1
# pexpect                       4.8.0
# phik                          0.12.2
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# playsound                     1.3.0
# plotly                        5.6.0
# pluggy                        1.0.0
# plumbum                       1.7.2
# poyo                          0.5.0
# preshed                       3.0.7
# prometheus-client             0.13.1
# promise                       2.3
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pycryptodome                  3.15.0
# pyct                          0.4.6
# pycurl                        7.44.1
# pydantic                      1.9.2
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# pymongo                       4.2.0
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# PyOpenGL                      3.1.1a1
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyreadline                    2.1
# pyresparser                   1.0.6
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-dotenv                 0.21.0
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# selenium                      4.5.0
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# spacy                         3.4.1
# spacy-legacy                  3.0.10
# spacy-loggers                 1.0.3
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# srsly                         2.4.4
# stack-data                    0.2.0
# statsmodels                   0.13.2
# stomp.py                      8.0.1
# sympy                         1.10.1
# tables                        3.6.1
# tabula-py                     2.5.1
# tabulate                      0.8.9
# tangled-up-in-unicode         0.2.0
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorflow-datasets           4.6.0
# tensorflow-metadata           1.10.0
# termcolor                     1.1.0
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# thinc                         8.1.2
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tika                          1.24
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# trio                          0.22.0
# trio-websocket                0.9.2
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typeguard                     2.13.3
# typer                         0.4.2
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# visions                       0.7.5
# w3lib                         1.21.0
# wasabi                        0.10.1
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webdriver-manager             3.8.3
# webdriver-setup               1.1.0
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# winapps                       0.2.0
# wincertstore                  0.2
# wrapt                         1.12.1
# wsproto                       1.2.0
# xarray                        0.20.1
# xgboost                       1.6.2
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# zict                          2.0.0
# zipp                          3.7.0
# zookeeper                     1.3.3
# zope.interface                5.4.0

# %%
soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')
# Out:
# [<td>Enguia</td>,
#  <td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>]

# %%
soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[1]
# Out:
# <td><a href="pdfs/contatos-enguia.pdf">Nossos contatos</a></td>

# %%
soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[1].find('a')
# Out:
# <a href="pdfs/contatos-enguia.pdf">Nossos contatos</a>

# %%
soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[1].find('a').get('href')
# Out:
# 'pdfs/contatos-enguia.pdf'

# %%
nome_pdf = soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[1].find('a').get('href')
arquivo = 'https://ocean-web-scraping.herokuapp.com/' + nome_pdf
arquivo
# 'C:/Users/sub13/Downloads/results/contatos-enguia.pdf'
# Out:
# 'https://ocean-web-scraping.herokuapp.com/pdfs/contatos-enguia.pdf'

# %%
import codecs
corretora_enguia_df = tabula.read_pdf(arquivo, encoding='utf-8' and 'latin-1', pages='all', stream=True)[0]
# df = read_pdf(file_path, java_options="-Dfile.encoding=UTF8")
#dfs2 = tabula.read_pdf('C:/Users/sub13/Downloads/results/contatos-enguia.pdf', pages="all", stream=True)
#dfs = tabula.read_pdf(pdf_path2, columns=[47, 147, 256, 310, 375, 431, 504], guess=False, pages=1)
#dfs = tabula.read_pdf('C:/Users/sub13/Downloads/results/contatos-enguia.pdf', columns=[1, 2, 3, 3], guess=False, pages=1)
#dfs1=tabula.read_pdf('C:/Users/sub13/Downloads/results/contatos-enguia.pdf', encoding='latin1', pages='all', stream=True)

#   encoding='latin1' for different lang format pdf else  'Utf-8'

# %%
corretora_enguia_df
# Out:
#        Corretor(a)             Contato
# 0      Bruna Maria  Fone:(XX)XXXX-XXXX
# 1  Carla Gonçalves  Fone:(XX)XXXX-XXXX
# 2       Zeca Gomes  Fone:(XX)XXXX-XXXX
# 3      Wagner Luiz  Fone:(XX)XXXX-XXXX
# 4     Marília Mota  Fone:(XX)XXXX-XXXX

# %%
corretora_enguia_df
# Out:
#        Corretor(a)             Contato
# 0      Bruna Maria  Fone:(XX)XXXX-XXXX
# 1  Carla Gonçalves  Fone:(XX)XXXX-XXXX
# 2       Zeca Gomes  Fone:(XX)XXXX-XXXX
# 3      Wagner Luiz  Fone:(XX)XXXX-XXXX
# 4     Marília Mota  Fone:(XX)XXXX-XXXX

# %%
print('Corretora: ', soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[0].get_text())

for nome,contato in zip(corretora_enguia_df['Corretor(a)'].to_list(),
                        corretora_enguia_df['Contato'].to_list()):
    print(nome)
    print(contato.replace('Fone:',''))
# Out:
# Corretora:  Enguia
# Bruna Maria
# (XX)XXXX-XXXX
# Carla Gonçalves
# (XX)XXXX-XXXX
# Zeca Gomes
# (XX)XXXX-XXXX
# Wagner Luiz
# (XX)XXXX-XXXX
# Marília Mota
# (XX)XXXX-XXXX

# %% [markdown]
# #### Saving data in lists

# %%
for nome,contato in zip(corretora_enguia_df['Corretor(a)'].to_list(),
                        corretora_enguia_df['Contato'].to_list()):
    lista_corretoras.append(soup_corretoras.find('tbody').find_all('tr')[3].find_all('td')[0].get_text())
    lista_nomes.append(nome)
    lista_contatos.append(contato.replace('Fone:',''))

# %%
lista_corretoras, lista_nomes, lista_contatos
# Out:
# (['Tubarão',
#   'Carangueijo',
#   'Carangueijo',
#   'Baleia Azul',
#   'Baleia Azul',
#   'Enguia',
#   'Enguia',
#   'Enguia',
#   'Enguia',
#   'Enguia'],
#  ['João Marinho',
#   'Ana Sirigueijo',
#   'Sebastião Costa',
#   'Alina Ferreira',
#   'Jorge Matheus',
#   'Bruna Maria',
#   'Carla Gonçalves',
#   'Zeca Gomes',
#   'Wagner Luiz',
#   'Marília Mota'],
#  ['(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX'])

# %% [markdown]
# #### 4.5) Persisting all brokerage information

# %%
contatos_corretoras_dict.update({'Corretoras': lista_corretoras,
                                 'Nomes': lista_nomes,
                                 'Contatos': lista_contatos})

contatos_corretoras_dict
# Out:
# {'Corretoras': ['Tubarão',
#   'Carangueijo',
#   'Carangueijo',
#   'Baleia Azul',
#   'Baleia Azul',
#   'Enguia',
#   'Enguia',
#   'Enguia',
#   'Enguia',
#   'Enguia'],
#  'Nomes': ['João Marinho',
#   'Ana Sirigueijo',
#   'Sebastião Costa',
#   'Alina Ferreira',
#   'Jorge Matheus',
#   'Bruna Maria',
#   'Carla Gonçalves',
#   'Zeca Gomes',
#   'Wagner Luiz',
#   'Marília Mota'],
#  'Contatos': ['(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX',
#   '(XX)XXXX-XXXX']}

# %%
contatos_corretoras_df = pd.DataFrame.from_dict(contatos_corretoras_dict)

contatos_corretoras_df
# Out:
#     Corretoras            Nomes       Contatos
# 0      Tubarão     João Marinho  (XX)XXXX-XXXX
# 1  Carangueijo   Ana Sirigueijo  (XX)XXXX-XXXX
# 2  Carangueijo  Sebastião Costa  (XX)XXXX-XXXX
# 3  Baleia Azul   Alina Ferreira  (XX)XXXX-XXXX
# 4  Baleia Azul    Jorge Matheus  (XX)XXXX-XXXX
# 5       Enguia      Bruna Maria  (XX)XXXX-XXXX
# 6       Enguia  Carla Gonçalves  (XX)XXXX-XXXX
# 7       Enguia       Zeca Gomes  (XX)XXXX-XXXX
# 8       Enguia      Wagner Luiz  (XX)XXXX-XXXX
# 9       Enguia     Marília Mota  (XX)XXXX-XXXX

# %%
contatos_corretoras_df.to_csv('./contatos_corretoras.csv', sep = ';', index = False, encoding = 'utf-8')

# %% [markdown]
# ### 5) Analysis of collected data

# %%
resultados_df
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 0    100        3          2              2       sim          sim      sim
# 1     60        2          2              1       sim          sim      não
# 2     50        1          1              1       sim          não      não
# 3     60        2          2              1       sim          sim      não
# 4    120        4          3              2       sim          sim      sim
# 5     40        1          1              0       não          sim      não
# 6     60        2          2              0       não          sim      não
# 7     60        2          1              1       sim          sim      não
# 8     60        2          2              1       sim          sim      não
# 9    100        3          3              1       sim          sim      não
# 10   100        2          2              1       sim          sim      sim
# 11    50        2          1              0       sim          sim      não
# 12    80        2          2              1       sim          sim      sim
# 13    70        2          2              1       sim          sim      não
# 14    60        2          1              1       sim          sim      não
# 15   100        3          3              2       sim          sim      sim
# 16    80        2          2              2       sim          sim      não
# 17    50        1          1              1       sim          não      não
# 18    70        2          2              1       sim          sim      não
# 19    70        2          2              1       sim          sim      não
# 20    40        1          1              0       não          não      sim
#
#    piscina churrasqueira salão de festas academia playground  \
# 0      sim           sim             sim      sim        sim
# 1      não           não             sim      não        não
# 2      não           não             não      não        não
# 3      não           não             não      não        não
# 4      sim           sim             sim      sim        sim
# 5      não           não             não      não        não
# 6      não           não             sim      não        não
# 7      sim           não             sim      não        não
# 8      não           não             não      não        não
# 9      sim           não             sim      sim        não
# 10     sim           não             sim      sim        não
# 11     não           não             não      não        não
# 12     sim           não             não      não        não
# 13     não           não             não      não        não
# 14     não           não             não      não        não
# 15     sim           sim             sim      sim        sim
# 16     não           não             sim      não        não
# 17     não           não             não      não        não
# 18     não           não             sim      não        não
# 19     não           não             sim      não        não
# 20     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 0                   sim            sim            sim   4000.0       500.0
# 1                   sim            não            não   2000.0       200.0
# 2                   não            não            não   1300.0       200.0
# 3                   não            não            não   1800.0       100.0
# 4                   sim            sim            sim   3800.0       500.0
# 5                   não            não            não    950.0        50.0
# 6                   sim            não            não   1100.0       100.0
# 7                   sim            não            não   1850.0       100.0
# 8                   não            não            não   1800.0       150.0
# 9                   sim            não            sim   3000.0       250.0
# 10                  não            não            sim   2800.0       220.0
# 11                  não            não            não   1300.0       100.0
# 12                  não            não            sim   1750.0       150.0
# 13                  não            não            não   1650.0       120.0
# 14                  não            não            sim   1250.0       100.0
# 15                  sim            sim            sim   3350.0       100.0
# 16                  sim            não            sim   2150.0       180.0
# 17                  não            não            não   1080.0       100.0
# 18                  sim            não            sim   2180.0       120.0
# 19                  não            não            sim   1900.0       100.0
# 20                  não            não            não    990.0        50.0
#
#      iptu    corretora       localizacao
# 0   100.0      Tubarão   Oceano Pacífico
# 1    50.0  Carangueijo     Oceano Índico
# 2    50.0  Baleia Azul       Mar de Java
# 3    20.0  Baleia Azul     Oceano Índico
# 4   200.0      Tubarão   Oceano Pacífico
# 5    10.0       Enguia  Mar Mediterrâneo
# 6    50.0       Enguia       Mar de Java
# 7    50.0  Carangueijo     Oceano Índico
# 8    50.0  Carangueijo     Oceano Índico
# 9    50.0      Tubarão   Oceano Pacífico
# 10   80.0      Tubarão  Oceano Atlântico
# 11   80.0       Enguia       Mar de Java
# 12   50.0  Baleia Azul       Mar de Java
# 13   20.0  Carangueijo  Oceano Atlântico
# 14   80.0       Enguia  Mar Mediterrâneo
# 15   50.0      Tubarão   Oceano Pacífico
# 16   20.0  Baleia Azul     Oceano Índico
# 17   20.0       Enguia  Mar Mediterrâneo
# 18   40.0  Carangueijo   Oceano Pacífico
# 19   20.0  Baleia Azul       Mar de Java
# 20   10.0       Enguia  Mar Mediterrâneo

# %% [markdown]
# #### 5.1) I would like to pay a maximum rent of BRL 1,800.00 and live in an apartment with at least 2 bedrooms and 1 parking space, in the Atlantic Ocean

# %%
busca = resultados_df['aluguel'] <= 1800
busca
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20     True
# Name: aluguel, dtype: bool

# %%
len(resultados_df.loc[busca])
# Out:
# 11

# %%
resultados_df.loc[busca]
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 2     50        1          1              1       sim          não      não
# 3     60        2          2              1       sim          sim      não
# 5     40        1          1              0       não          sim      não
# 6     60        2          2              0       não          sim      não
# 8     60        2          2              1       sim          sim      não
# 11    50        2          1              0       sim          sim      não
# 12    80        2          2              1       sim          sim      sim
# 13    70        2          2              1       sim          sim      não
# 14    60        2          1              1       sim          sim      não
# 17    50        1          1              1       sim          não      não
# 20    40        1          1              0       não          não      sim
#
#    piscina churrasqueira salão de festas academia playground  \
# 2      não           não             não      não        não
# 3      não           não             não      não        não
# 5      não           não             não      não        não
# 6      não           não             sim      não        não
# 8      não           não             não      não        não
# 11     não           não             não      não        não
# 12     sim           não             não      não        não
# 13     não           não             não      não        não
# 14     não           não             não      não        não
# 17     não           não             não      não        não
# 20     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 2                   não            não            não   1300.0       200.0
# 3                   não            não            não   1800.0       100.0
# 5                   não            não            não    950.0        50.0
# 6                   sim            não            não   1100.0       100.0
# 8                   não            não            não   1800.0       150.0
# 11                  não            não            não   1300.0       100.0
# 12                  não            não            sim   1750.0       150.0
# 13                  não            não            não   1650.0       120.0
# 14                  não            não            sim   1250.0       100.0
# 17                  não            não            não   1080.0       100.0
# 20                  não            não            não    990.0        50.0
#
#     iptu    corretora       localizacao
# 2   50.0  Baleia Azul       Mar de Java
# 3   20.0  Baleia Azul     Oceano Índico
# 5   10.0       Enguia  Mar Mediterrâneo
# 6   50.0       Enguia       Mar de Java
# 8   50.0  Carangueijo     Oceano Índico
# 11  80.0       Enguia       Mar de Java
# 12  50.0  Baleia Azul       Mar de Java
# 13  20.0  Carangueijo  Oceano Atlântico
# 14  80.0       Enguia  Mar Mediterrâneo
# 17  20.0       Enguia  Mar Mediterrâneo
# 20  10.0       Enguia  Mar Mediterrâneo

# %%
busca = ((resultados_df['aluguel'] <= 1800) & (resultados_df['quartos'] >= 2))

# %%
len(resultados_df.loc[busca])
# Out:
# 7

# %%
resultados_df.loc[busca]
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 3     60        2          2              1       sim          sim      não
# 6     60        2          2              0       não          sim      não
# 8     60        2          2              1       sim          sim      não
# 11    50        2          1              0       sim          sim      não
# 12    80        2          2              1       sim          sim      sim
# 13    70        2          2              1       sim          sim      não
# 14    60        2          1              1       sim          sim      não
#
#    piscina churrasqueira salão de festas academia playground  \
# 3      não           não             não      não        não
# 6      não           não             sim      não        não
# 8      não           não             não      não        não
# 11     não           não             não      não        não
# 12     sim           não             não      não        não
# 13     não           não             não      não        não
# 14     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 3                   não            não            não   1800.0       100.0
# 6                   sim            não            não   1100.0       100.0
# 8                   não            não            não   1800.0       150.0
# 11                  não            não            não   1300.0       100.0
# 12                  não            não            sim   1750.0       150.0
# 13                  não            não            não   1650.0       120.0
# 14                  não            não            sim   1250.0       100.0
#
#     iptu    corretora       localizacao
# 3   20.0  Baleia Azul     Oceano Índico
# 6   50.0       Enguia       Mar de Java
# 8   50.0  Carangueijo     Oceano Índico
# 11  80.0       Enguia       Mar de Java
# 12  50.0  Baleia Azul       Mar de Java
# 13  20.0  Carangueijo  Oceano Atlântico
# 14  80.0       Enguia  Mar Mediterrâneo

# %%
busca = ((resultados_df['aluguel'] <= 1800) & 
         (resultados_df['quartos'] >= 2) & 
         (resultados_df['vagas garagem'] >= 1))

# %%
len(resultados_df.loc[busca])
# Out:
# 5

# %%
resultados_df.loc[busca]
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 3     60        2          2              1       sim          sim      não
# 8     60        2          2              1       sim          sim      não
# 12    80        2          2              1       sim          sim      sim
# 13    70        2          2              1       sim          sim      não
# 14    60        2          1              1       sim          sim      não
#
#    piscina churrasqueira salão de festas academia playground  \
# 3      não           não             não      não        não
# 8      não           não             não      não        não
# 12     sim           não             não      não        não
# 13     não           não             não      não        não
# 14     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 3                   não            não            não   1800.0       100.0
# 8                   não            não            não   1800.0       150.0
# 12                  não            não            sim   1750.0       150.0
# 13                  não            não            não   1650.0       120.0
# 14                  não            não            sim   1250.0       100.0
#
#     iptu    corretora       localizacao
# 3   20.0  Baleia Azul     Oceano Índico
# 8   50.0  Carangueijo     Oceano Índico
# 12  50.0  Baleia Azul       Mar de Java
# 13  20.0  Carangueijo  Oceano Atlântico
# 14  80.0       Enguia  Mar Mediterrâneo

# %%
busca = ((resultados_df['aluguel'] <= 1800) & 
         (resultados_df['quartos'] >= 2) & 
         (resultados_df['vagas garagem'] >= 1) &
         (resultados_df['localizacao'] == 'Oceano Atlântico'))

# %%
len(resultados_df.loc[busca])
# Out:
# 1

# %%
resultados_df.loc[busca]
# Out:
#     área  quartos  banheiros  vagas garagem mobiliado portaria 24h elevador  \
# 13    70        2          2              1       sim          sim      não
#
#    piscina churrasqueira salão de festas academia playground  \
# 13     não           não             não      não        não
#
#    quadra poliesportiva salão de jogos aceita animais  aluguel  condomínio  \
# 13                  não            não            não   1650.0       120.0
#
#     iptu    corretora       localizacao
# 13  20.0  Carangueijo  Oceano Atlântico

# %% [markdown]
# #### Contacting brokers

# %%
contatos_corretoras_df
# Out:
#     Corretoras            Nomes       Contatos
# 0      Tubarão     João Marinho  (XX)XXXX-XXXX
# 1  Carangueijo   Ana Sirigueijo  (XX)XXXX-XXXX
# 2  Carangueijo  Sebastião Costa  (XX)XXXX-XXXX
# 3  Baleia Azul   Alina Ferreira  (XX)XXXX-XXXX
# 4  Baleia Azul    Jorge Matheus  (XX)XXXX-XXXX
# 5       Enguia      Bruna Maria  (XX)XXXX-XXXX
# 6       Enguia  Carla Gonçalves  (XX)XXXX-XXXX
# 7       Enguia       Zeca Gomes  (XX)XXXX-XXXX
# 8       Enguia      Wagner Luiz  (XX)XXXX-XXXX
# 9       Enguia     Marília Mota  (XX)XXXX-XXXX

# %%
busca_corretora = contatos_corretoras_df['Corretoras'] == 'Carangueijo'

# %%
contatos_corretoras_df.loc[busca_corretora]
# Out:
#     Corretoras            Nomes       Contatos
# 1  Carangueijo   Ana Sirigueijo  (XX)XXXX-XXXX
# 2  Carangueijo  Sebastião Costa  (XX)XXXX-XXXX

# %% [markdown]
# ### 6) Examples of other analyzes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(font_scale=1.4)
sns.set_style({'font.family': 'serif',
               'fontname': 'Times New Roman'})

# %% [markdown]
# ### Who has more/less properties?

# %%
resultados_df['localizacao'].value_counts()
# Out:
# Oceano Pacífico     5
# Oceano Índico       5
# Mar de Java         5
# Mar Mediterrâneo    4
# Oceano Atlântico    2
# Name: localizacao, dtype: int64

# %%
resultados_df['localizacao'].value_counts().sort_values().plot(kind = 'barh', 
                                                               figsize=(8, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the locations with the largest/smallest properties and the cheapest/expensive properties?

# %%
fig_dims = (8, 6)
fig, ax = plt.subplots(figsize=fig_dims)

sns.scatterplot(data = resultados_df, 
                x = 'área', 
                y = 'aluguel', 
                hue = 'localizacao',
                s = 200,
                ax = ax)
# Out:
# <AxesSubplot:xlabel='área', ylabel='aluguel'>
